# %% [markdown]
# ### Data cleaning and preprocessing with Pandas

# %%
import pandas as pd

# %%
cereal_data = pd.read_csv('cereal.csv')

# %%
cereal_data.head(3)
# Out:
#                 name mfr type  calories  protein  fat  sodium  fiber  carbo  \
# 0          100% Bran   N    C        70        4    1     130   10.0    5.0
# 1  100% Natural Bran   Q    C       120        3    5      15    2.0    8.0
# 2           All-Bran   K    C        70        4    1     260    9.0    7.0
#
#    sugars  potass  vitamins  shelf  weight  cups     rating
# 0       6     280        25      3     1.0  0.33  68.402973
# 1       8     135         0      3     1.0  1.00  33.983679
# 2       5     320        25      3     1.0  0.33  59.425505

# %%
basic_stats = cereal_data.describe()
basic_stats
# Out:
#          calories    protein        fat      sodium      fiber      carbo  \
# count   77.000000  77.000000  77.000000   77.000000  77.000000  77.000000
# mean   106.883117   2.545455   1.012987  159.675325   2.151948  14.597403
# std     19.484119   1.094790   1.006473   83.832295   2.383364   4.278956
# min     50.000000   1.000000   0.000000    0.000000   0.000000  -1.000000
# 25%    100.000000   2.000000   0.000000  130.000000   1.000000  12.000000
# 50%    110.000000   3.000000   1.000000  180.000000   2.000000  14.000000
# 75%    110.000000   3.000000   2.000000  210.000000   3.000000  17.000000
# max    160.000000   6.000000   5.000000  320.000000  14.000000  23.000000
#
#           sugars      potass    vitamins      shelf     weight       cups  \
# count  77.000000   77.000000   77.000000  77.000000  77.000000  77.000000
# mean    6.922078   96.077922   28.246753   2.207792   1.029610   0.821039
# std     4.444885   71.286813   22.342523   0.832524   0.150477   0.232716
# min    -1.000000   -1.000000    0.000000   1.000000   0.500000   0.250000
# 25%     3.000000   40.000000   25.000000   1.000000   1.000000   0.670000
# 50%     7.000000   90.000000   25.000000   2.000000   1.000000   0.750000
# 75%    11.000000  120.000000   25.000000   3.000000   1.000000   1.000000
# max    15.000000  330.000000  100.000000   3.000000   1.500000   1.500000
#
#           rating
# count  77.000000
# mean   42.665705
# std    14.047289
# min    18.042851
# 25%    33.174094
# 50%    40.400208
# 75%    50.828392
# max    93.704912

# %% [markdown]
# #### Identify missing values in the DataFrame

# %%
missing_values = cereal_data.isnull().sum()
missing_values
# Out:
# name        0
# mfr         0
# type        0
# calories    0
# protein     0
# fat         0
# sodium      0
# fiber       0
# carbo       0
# sugars      0
# potass      0
# vitamins    0
# shelf       0
# weight      0
# cups        0
# rating      0
# dtype: int64

# %% [markdown]
# #### Drop rows and columns with any missing values

# %%
dropped_rows_df = cereal_data.dropna()
dropped_columns_df = cereal_data.dropna(axis=1)
# all data nothing is missing 
dropped_rows_df 
dropped_columns_df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %% [markdown]
# #### Fill missing values

# %%
filled_values_df = cereal_data.fillna(0) #with 0
# Forward and Backward fill method
ffill_df = cereal_data.fillna(method='ffill')
bfill_df = cereal_data.fillna(method='bfill')

# %%
# Interpolate missing values
interpolated_df = cereal_data.interpolate()
interpolated_df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
# Convert the 'calories' column to float
cereal_data['calories'] = cereal_data['calories'].astype(float)
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C      70.0        4    1     130   10.0
# 1           100% Natural Bran   Q    C     120.0        3    5      15    2.0
# 2                    All-Bran   K    C      70.0        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C      50.0        4    0     140   14.0
# 4              Almond Delight   R    C     110.0        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C     110.0        2    1     250    0.0
# 73                       Trix   G    C     110.0        1    1     140    0.0
# 74                 Wheat Chex   R    C     100.0        3    1     230    3.0
# 75                   Wheaties   G    C     100.0        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C     110.0        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
# [77 rows x 16 columns]

# %%
# Apply a lambda function to transform the values of the 'calories' column I multiplied by 2
transformed_df = cereal_data.copy()
transformed_df['calories101'] = transformed_df['calories'].apply(lambda x: x * 2)

# %%
# Min-Max scaling for the 'calories' column
cereal_data['calories_minmax'] = (cereal_data['calories'] - cereal_data['calories'].min()) / (cereal_data['calories'].max() - cereal_data['calories'].min())
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
#     calories_minmax
# 0          0.181818
# 1          0.636364
# 2          0.181818
# 3          0.000000
# 4          0.545455
# ..              ...
# 72         0.545455
# 73         0.545455
# 74         0.454545
# 75         0.454545
# 76         0.545455
#
# [77 rows x 17 columns]

# %%
# Z-score normalization for the calories column
cereal_data['calories_zscore'] = (cereal_data['calories'] - cereal_data['calories'].mean()) / cereal_data['calories'].std()
cereal_data
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
#     calories_minmax  calories_zscore
# 0          0.181818        -1.892984
# 1          0.636364         0.673209
# 2          0.181818        -1.892984
# 3          0.000000        -2.919461
# 4          0.545455         0.159970
# ..              ...              ...
# 72         0.545455         0.159970
# 73         0.545455         0.159970
# 74         0.454545        -0.353268
# 75         0.454545        -0.353268
# 76         0.545455         0.159970
#
# [77 rows x 18 columns]

# %%
# Identify duplicate rows
duplicate_rows = cereal_data[cereal_data.duplicated()]
duplicate_rows # no duplicates
# Out:
# Empty DataFrame
# Columns: [name, mfr, type, calories, protein, fat, sodium, fiber, carbo, sugars, potass, vitamins, shelf, weight, cups, rating, calories_minmax, calories_zscore]
# Index: []

# %%
# Drop duplicate rows
dropped_duplicates_df = cereal_data.drop_duplicates()
dropped_duplicates_df

# Drop duplicate rows of 'name' column
dropped_duplicates_name_df = cereal_data.drop_duplicates(subset=['name'])
dropped_duplicates_name_df
# Out:
#                          name mfr type  calories  protein  fat  sodium  fiber  \
# 0                   100% Bran   N    C        70        4    1     130   10.0
# 1           100% Natural Bran   Q    C       120        3    5      15    2.0
# 2                    All-Bran   K    C        70        4    1     260    9.0
# 3   All-Bran with Extra Fiber   K    C        50        4    0     140   14.0
# 4              Almond Delight   R    C       110        2    2     200    1.0
# ..                        ...  ..  ...       ...      ...  ...     ...    ...
# 72                    Triples   G    C       110        2    1     250    0.0
# 73                       Trix   G    C       110        1    1     140    0.0
# 74                 Wheat Chex   R    C       100        3    1     230    3.0
# 75                   Wheaties   G    C       100        3    1     200    3.0
# 76        Wheaties Honey Gold   G    C       110        2    1     200    1.0
#
#     carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0     5.0       6     280        25      3     1.0  0.33  68.402973
# 1     8.0       8     135         0      3     1.0  1.00  33.983679
# 2     7.0       5     320        25      3     1.0  0.33  59.425505
# 3     8.0       0     330        25      3     1.0  0.50  93.704912
# 4    14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...     ...     ...       ...    ...     ...   ...        ...
# 72   21.0       3      60        25      3     1.0  0.75  39.106174
# 73   13.0      12      25        25      2     1.0  1.00  27.753301
# 74   17.0       3     115        25      1     1.0  0.67  49.787445
# 75   17.0       3     110        25      1     1.0  1.00  51.592193
# 76   16.0       8      60        25      1     1.0  0.75  36.187559
#
#     calories_minmax  calories_zscore
# 0          0.181818        -1.892984
# 1          0.636364         0.673209
# 2          0.181818        -1.892984
# 3          0.000000        -2.919461
# 4          0.545455         0.159970
# ..              ...              ...
# 72         0.545455         0.159970
# 73         0.545455         0.159970
# 74         0.454545        -0.353268
# 75         0.454545        -0.353268
# 76         0.545455         0.159970
#
# [77 rows x 18 columns]

# %%
# Convert all string values in the 'name' column to lowercase
cereal_data['name'] = cereal_data['name'].str.lower()
# Remove leading and trailing spaces from string values in the 'name' column
cereal_data['name'] = cereal_data['name'].str.strip()
# Replace 'bran' with 'fiber' in the 'name' column
cereal_data['name'] = cereal_data['name'].str.replace('bran', 'fiber', case=False)
cereal_data
# Out:
#                           name mfr type  calories  protein  fat  sodium  \
# 0                   100% fiber   N    C        70        4    1     130
# 1           100% natural fiber   Q    C       120        3    5      15
# 2                    all-fiber   K    C        70        4    1     260
# 3   all-fiber with extra fiber   K    C        50        4    0     140
# 4               almond delight   R    C       110        2    2     200
# ..                         ...  ..  ...       ...      ...  ...     ...
# 72                     triples   G    C       110        2    1     250
# 73                        trix   G    C       110        1    1     140
# 74                  wheat chex   R    C       100        3    1     230
# 75                    wheaties   G    C       100        3    1     200
# 76         wheaties honey gold   G    C       110        2    1     200
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    10.0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1     2.0    8.0       8     135         0      3     1.0  1.00  33.983679
# 2     9.0    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    14.0    8.0       0     330        25      3     1.0  0.50  93.704912
# 4     1.0   14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...    ...     ...     ...       ...    ...     ...   ...        ...
# 72    0.0   21.0       3      60        25      3     1.0  0.75  39.106174
# 73    0.0   13.0      12      25        25      2     1.0  1.00  27.753301
# 74    3.0   17.0       3     115        25      1     1.0  0.67  49.787445
# 75    3.0   17.0       3     110        25      1     1.0  1.00  51.592193
# 76    1.0   16.0       8      60        25      1     1.0  0.75  36.187559
#
#     calories_minmax  calories_zscore
# 0          0.181818        -1.892984
# 1          0.636364         0.673209
# 2          0.181818        -1.892984
# 3          0.000000        -2.919461
# 4          0.545455         0.159970
# ..              ...              ...
# 72         0.545455         0.159970
# 73         0.545455         0.159970
# 74         0.454545        -0.353268
# 75         0.454545        -0.353268
# 76         0.545455         0.159970
#
# [77 rows x 18 columns]

# %%
# Extract the first 3 characters from the 'name' column
cereal_data['name_prefix'] = cereal_data['name'].str[:3]
cereal_data
# Out:
#                           name mfr type  calories  protein  fat  sodium  \
# 0                   100% fiber   N    C        70        4    1     130
# 1           100% natural fiber   Q    C       120        3    5      15
# 2                    all-fiber   K    C        70        4    1     260
# 3   all-fiber with extra fiber   K    C        50        4    0     140
# 4               almond delight   R    C       110        2    2     200
# ..                         ...  ..  ...       ...      ...  ...     ...
# 72                     triples   G    C       110        2    1     250
# 73                        trix   G    C       110        1    1     140
# 74                  wheat chex   R    C       100        3    1     230
# 75                    wheaties   G    C       100        3    1     200
# 76         wheaties honey gold   G    C       110        2    1     200
#
#     fiber  carbo  sugars  potass  vitamins  shelf  weight  cups     rating  \
# 0    10.0    5.0       6     280        25      3     1.0  0.33  68.402973
# 1     2.0    8.0       8     135         0      3     1.0  1.00  33.983679
# 2     9.0    7.0       5     320        25      3     1.0  0.33  59.425505
# 3    14.0    8.0       0     330        25      3     1.0  0.50  93.704912
# 4     1.0   14.0       8      -1        25      3     1.0  0.75  34.384843
# ..    ...    ...     ...     ...       ...    ...     ...   ...        ...
# 72    0.0   21.0       3      60        25      3     1.0  0.75  39.106174
# 73    0.0   13.0      12      25        25      2     1.0  1.00  27.753301
# 74    3.0   17.0       3     115        25      1     1.0  0.67  49.787445
# 75    3.0   17.0       3     110        25      1     1.0  1.00  51.592193
# 76    1.0   16.0       8      60        25      1     1.0  0.75  36.187559
#
#     calories_minmax  calories_zscore name_prefix
# 0          0.181818        -1.892984         100
# 1          0.636364         0.673209         100
# 2          0.181818        -1.892984         all
# 3          0.000000        -2.919461         all
# 4          0.545455         0.159970         alm
# ..              ...              ...         ...
# 72         0.545455         0.159970         tri
# 73         0.545455         0.159970         tri
# 74         0.454545        -0.353268         whe
# 75         0.454545        -0.353268         whe
# 76         0.545455         0.159970         whe
#
# [77 rows x 19 columns]

# %%
# Creating a new column 'calories_per_gram' based on 'calories' and 'weight'
cereal_data['calories_per_gram'] = cereal_data['calories'] / (cereal_data['weight'] * 28.3495)  # 1 ounce = 28.3495 grams
# Discretizing the 'calories' column into 3 bins
cereal_data['calories_binned'] = pd.cut(cereal_data['calories'], bins=3, labels=['low', 'medium', 'high'])
cereal_data
# Out:
#                           name mfr type  calories  protein  fat  sodium  \
# 0                   100% fiber   N    C        70        4    1     130
# 1           100% natural fiber   Q    C       120        3    5      15
# 2                    all-fiber   K    C        70        4    1     260
# 3   all-fiber with extra fiber   K    C        50        4    0     140
# 4               almond delight   R    C       110        2    2     200
# ..                         ...  ..  ...       ...      ...  ...     ...
# 72                     triples   G    C       110        2    1     250
# 73                        trix   G    C       110        1    1     140
# 74                  wheat chex   R    C       100        3    1     230
# 75                    wheaties   G    C       100        3    1     200
# 76         wheaties honey gold   G    C       110        2    1     200
#
#     fiber  carbo  sugars  ...  vitamins  shelf  weight  cups     rating  \
# 0    10.0    5.0       6  ...        25      3     1.0  0.33  68.402973
# 1     2.0    8.0       8  ...         0      3     1.0  1.00  33.983679
# 2     9.0    7.0       5  ...        25      3     1.0  0.33  59.425505
# 3    14.0    8.0       0  ...        25      3     1.0  0.50  93.704912
# 4     1.0   14.0       8  ...        25      3     1.0  0.75  34.384843
# ..    ...    ...     ...  ...       ...    ...     ...   ...        ...
# 72    0.0   21.0       3  ...        25      3     1.0  0.75  39.106174
# 73    0.0   13.0      12  ...        25      2     1.0  1.00  27.753301
# 74    3.0   17.0       3  ...        25      1     1.0  0.67  49.787445
# 75    3.0   17.0       3  ...        25      1     1.0  1.00  51.592193
# 76    1.0   16.0       8  ...        25      1     1.0  0.75  36.187559
#
#     calories_minmax  calories_zscore  name_prefix calories_per_gram  \
# 0          0.181818        -1.892984          100          2.469179
# 1          0.636364         0.673209          100          4.232879
# 2          0.181818        -1.892984          all          2.469179
# 3          0.000000        -2.919461          all          1.763700
# 4          0.545455         0.159970          alm          3.880139
# ..              ...              ...          ...               ...
# 72         0.545455         0.159970          tri          3.880139
# 73         0.545455         0.159970          tri          3.880139
# 74         0.454545        -0.353268          whe          3.527399
# 75         0.454545        -0.353268          whe          3.527399
# 76         0.545455         0.159970          whe          3.880139
#
#     calories_binned
# 0               low
# 1            medium
# 2               low
# 3               low
# 4            medium
# ..              ...
# 72           medium
# 73           medium
# 74           medium
# 75           medium
# 76           medium
#
# [77 rows x 21 columns]

# %%
# DataFrame concatenation
df2  = pd.read_csv('Dataset salary 2024.csv')
concatenated_df = pd.concat([cereal_data, df2], axis=0)
concatenated_df
# Out:
#                              name  mfr type  calories  protein  fat  sodium  \
# 0                      100% fiber    N    C      70.0      4.0  1.0   130.0
# 1              100% natural fiber    Q    C     120.0      3.0  5.0    15.0
# 2                       all-fiber    K    C      70.0      4.0  1.0   260.0
# 3      all-fiber with extra fiber    K    C      50.0      4.0  0.0   140.0
# 4                  almond delight    R    C     110.0      2.0  2.0   200.0
# ...                           ...  ...  ...       ...      ...  ...     ...
# 16529                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 16530                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 16531                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 16532                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 16533                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
#
#        fiber  carbo  sugars  ...  experience_level  employment_type  \
# 0       10.0    5.0     6.0  ...               NaN              NaN
# 1        2.0    8.0     8.0  ...               NaN              NaN
# 2        9.0    7.0     5.0  ...               NaN              NaN
# 3       14.0    8.0     0.0  ...               NaN              NaN
# 4        1.0   14.0     8.0  ...               NaN              NaN
# ...      ...    ...     ...  ...               ...              ...
# 16529    NaN    NaN     NaN  ...                SE               FT
# 16530    NaN    NaN     NaN  ...                MI               FT
# 16531    NaN    NaN     NaN  ...                EN               FT
# 16532    NaN    NaN     NaN  ...                EN               CT
# 16533    NaN    NaN     NaN  ...                SE               FT
#
#                       job_title     salary  salary_currency  salary_in_usd  \
# 0                           NaN        NaN              NaN            NaN
# 1                           NaN        NaN              NaN            NaN
# 2                           NaN        NaN              NaN            NaN
# 3                           NaN        NaN              NaN            NaN
# 4                           NaN        NaN              NaN            NaN
# ...                         ...        ...              ...            ...
# 16529            Data Scientist   412000.0              USD       412000.0
# 16530  Principal Data Scientist   151000.0              USD       151000.0
# 16531            Data Scientist   105000.0              USD       105000.0
# 16532     Business Data Analyst   100000.0              USD       100000.0
# 16533      Data Science Manager  7000000.0              INR        94665.0
#
#        employee_residence  remote_ratio company_location  company_size
# 0                     NaN           NaN              NaN           NaN
# 1                     NaN           NaN              NaN           NaN
# 2                     NaN           NaN              NaN           NaN
# 3                     NaN           NaN              NaN           NaN
# 4                     NaN           NaN              NaN           NaN
# ...                   ...           ...              ...           ...
# 16529                  US         100.0               US             L
# 16530                  US         100.0               US             L
# 16531                  US         100.0               US             S
# 16532                  US         100.0               US             L
# 16533                  IN          50.0               IN             L
#
# [16611 rows x 32 columns]

# %%
concatenated_horizontal_df = pd.concat([cereal_data, df2], axis=1)
concatenated_horizontal_df
# Out:
#                              name  mfr type  calories  protein  fat  sodium  \
# 0                      100% fiber    N    C      70.0      4.0  1.0   130.0
# 1              100% natural fiber    Q    C     120.0      3.0  5.0    15.0
# 2                       all-fiber    K    C      70.0      4.0  1.0   260.0
# 3      all-fiber with extra fiber    K    C      50.0      4.0  0.0   140.0
# 4                  almond delight    R    C     110.0      2.0  2.0   200.0
# ...                           ...  ...  ...       ...      ...  ...     ...
# 16529                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 16530                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 16531                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 16532                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
# 16533                         NaN  NaN  NaN       NaN      NaN  NaN     NaN
#
#        fiber  carbo  sugars  ...  experience_level  employment_type  \
# 0       10.0    5.0     6.0  ...                SE               FT
# 1        2.0    8.0     8.0  ...                SE               FT
# 2        9.0    7.0     5.0  ...                SE               FT
# 3       14.0    8.0     0.0  ...                SE               FT
# 4        1.0   14.0     8.0  ...                SE               FT
# ...      ...    ...     ...  ...               ...              ...
# 16529    NaN    NaN     NaN  ...                SE               FT
# 16530    NaN    NaN     NaN  ...                MI               FT
# 16531    NaN    NaN     NaN  ...                EN               FT
# 16532    NaN    NaN     NaN  ...                EN               CT
# 16533    NaN    NaN     NaN  ...                SE               FT
#
#                        job_title   salary  salary_currency  salary_in_usd  \
# 0                    AI Engineer   202730              USD         202730
# 1                    AI Engineer    92118              USD          92118
# 2                  Data Engineer   130500              USD         130500
# 3                  Data Engineer    96000              USD          96000
# 4      Machine Learning Engineer   190000              USD         190000
# ...                          ...      ...              ...            ...
# 16529             Data Scientist   412000              USD         412000
# 16530   Principal Data Scientist   151000              USD         151000
# 16531             Data Scientist   105000              USD         105000
# 16532      Business Data Analyst   100000              USD         100000
# 16533       Data Science Manager  7000000              INR          94665
#
#        employee_residence  remote_ratio company_location  company_size
# 0                      US             0               US             M
# 1                      US             0               US             M
# 2                      US             0               US             M
# 3                      US             0               US             M
# 4                      US             0               US             M
# ...                   ...           ...              ...           ...
# 16529                  US           100               US             L
# 16530                  US           100               US             L
# 16531                  US           100               US             S
# 16532                  US           100               US             L
# 16533                  IN            50               IN             L
#
# [16534 rows x 32 columns]

# %%
# Creating a new column 'calories_per_gram' based on 'calories' and 'weight'
cereal_data['calories_per_gram'] = cereal_data['calories'] / (cereal_data['weight'] * 28.3495)  # 1 ounce = 28.3495 grams
cereal_data
# Out:
#                           name mfr type  calories  protein  fat  sodium  \
# 0                   100% fiber   N    C        70        4    1     130
# 1           100% natural fiber   Q    C       120        3    5      15
# 2                    all-fiber   K    C        70        4    1     260
# 3   all-fiber with extra fiber   K    C        50        4    0     140
# 4               almond delight   R    C       110        2    2     200
# ..                         ...  ..  ...       ...      ...  ...     ...
# 72                     triples   G    C       110        2    1     250
# 73                        trix   G    C       110        1    1     140
# 74                  wheat chex   R    C       100        3    1     230
# 75                    wheaties   G    C       100        3    1     200
# 76         wheaties honey gold   G    C       110        2    1     200
#
#     fiber  carbo  sugars  ...  vitamins  shelf  weight  cups     rating  \
# 0    10.0    5.0       6  ...        25      3     1.0  0.33  68.402973
# 1     2.0    8.0       8  ...         0      3     1.0  1.00  33.983679
# 2     9.0    7.0       5  ...        25      3     1.0  0.33  59.425505
# 3    14.0    8.0       0  ...        25      3     1.0  0.50  93.704912
# 4     1.0   14.0       8  ...        25      3     1.0  0.75  34.384843
# ..    ...    ...     ...  ...       ...    ...     ...   ...        ...
# 72    0.0   21.0       3  ...        25      3     1.0  0.75  39.106174
# 73    0.0   13.0      12  ...        25      2     1.0  1.00  27.753301
# 74    3.0   17.0       3  ...        25      1     1.0  0.67  49.787445
# 75    3.0   17.0       3  ...        25      1     1.0  1.00  51.592193
# 76    1.0   16.0       8  ...        25      1     1.0  0.75  36.187559
#
#     calories_minmax  calories_zscore  name_prefix calories_per_gram  \
# 0          0.181818        -1.892984          100          2.469179
# 1          0.636364         0.673209          100          4.232879
# 2          0.181818        -1.892984          all          2.469179
# 3          0.000000        -2.919461          all          1.763700
# 4          0.545455         0.159970          alm          3.880139
# ..              ...              ...          ...               ...
# 72         0.545455         0.159970          tri          3.880139
# 73         0.545455         0.159970          tri          3.880139
# 74         0.454545        -0.353268          whe          3.527399
# 75         0.454545        -0.353268          whe          3.527399
# 76         0.545455         0.159970          whe          3.880139
#
#     calories_binned
# 0               low
# 1            medium
# 2               low
# 3               low
# 4            medium
# ..              ...
# 72           medium
# 73           medium
# 74           medium
# 75           medium
# 76           medium
#
# [77 rows x 21 columns]

# %%
# Discretizing the 'calories' column into 3 bins
cereal_data['calories_binned'] = pd.cut(cereal_data['calories'], bins=3, labels=['low', 'medium', 'high'])
cereal_data
# Out:
#                           name mfr type  calories  protein  fat  sodium  \
# 0                   100% fiber   N    C        70        4    1     130
# 1           100% natural fiber   Q    C       120        3    5      15
# 2                    all-fiber   K    C        70        4    1     260
# 3   all-fiber with extra fiber   K    C        50        4    0     140
# 4               almond delight   R    C       110        2    2     200
# ..                         ...  ..  ...       ...      ...  ...     ...
# 72                     triples   G    C       110        2    1     250
# 73                        trix   G    C       110        1    1     140
# 74                  wheat chex   R    C       100        3    1     230
# 75                    wheaties   G    C       100        3    1     200
# 76         wheaties honey gold   G    C       110        2    1     200
#
#     fiber  carbo  sugars  ...  vitamins  shelf  weight  cups     rating  \
# 0    10.0    5.0       6  ...        25      3     1.0  0.33  68.402973
# 1     2.0    8.0       8  ...         0      3     1.0  1.00  33.983679
# 2     9.0    7.0       5  ...        25      3     1.0  0.33  59.425505
# 3    14.0    8.0       0  ...        25      3     1.0  0.50  93.704912
# 4     1.0   14.0       8  ...        25      3     1.0  0.75  34.384843
# ..    ...    ...     ...  ...       ...    ...     ...   ...        ...
# 72    0.0   21.0       3  ...        25      3     1.0  0.75  39.106174
# 73    0.0   13.0      12  ...        25      2     1.0  1.00  27.753301
# 74    3.0   17.0       3  ...        25      1     1.0  0.67  49.787445
# 75    3.0   17.0       3  ...        25      1     1.0  1.00  51.592193
# 76    1.0   16.0       8  ...        25      1     1.0  0.75  36.187559
#
#     calories_minmax  calories_zscore  name_prefix calories_per_gram  \
# 0          0.181818        -1.892984          100          2.469179
# 1          0.636364         0.673209          100          4.232879
# 2          0.181818        -1.892984          all          2.469179
# 3          0.000000        -2.919461          all          1.763700
# 4          0.545455         0.159970          alm          3.880139
# ..              ...              ...          ...               ...
# 72         0.545455         0.159970          tri          3.880139
# 73         0.545455         0.159970          tri          3.880139
# 74         0.454545        -0.353268          whe          3.527399
# 75         0.454545        -0.353268          whe          3.527399
# 76         0.545455         0.159970          whe          3.880139
#
#     calories_binned
# 0               low
# 1            medium
# 2               low
# 3               low
# 4            medium
# ..              ...
# 72           medium
# 73           medium
# 74           medium
# 75           medium
# 76           medium
#
# [77 rows x 21 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures

# Creating polynomial features from 'calories' and 'protein' columns
poly = PolynomialFeatures(degree=2)
poly_features = poly.fit_transform(cereal_data[['calories', 'protein']])
poly_features_df = pd.DataFrame(poly_features, columns=poly.get_feature_names_out(['calories', 'protein']))

print(poly_features_df.head())
# Out:
#      1  calories  protein  calories^2  calories protein  protein^2
# 0  1.0      70.0      4.0      4900.0             280.0       16.0
# 1  1.0     120.0      3.0     14400.0             360.0        9.0
# 2  1.0      70.0      4.0      4900.0             280.0       16.0
# 3  1.0      50.0      4.0      2500.0             200.0       16.0
# 4  1.0     110.0      2.0     12100.0             220.0        4.0
